# %%
pip install --index-url https://test.pypi.org/simple/ --no-deps --upgrade  --force-reinstall algothon2021
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Collecting algothon2021
#   Downloading https://test-files.pythonhosted.org/packages/c9/4a/040719980a609c107b3b4fc0bc431600559e68f8f83b5629efb81b6afe63/algothon2021-0.0.6-py3-none-any.whl (74.5 MB)
#      |████████████████████████████████| 74.5 MB 9.0 MB/s
# Installing collected packages: algothon2021
# Successfully installed algothon2021-0.0.6
# WARNING: You are using pip version 20.2.1; however, version 21.0.1 is available.
# You should consider upgrading via the '/Users/frederik/Desktop/AlgothonML/env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## ML challenge

# %%
from algothon2021ml import ML
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-382628615fe2> in <module>
# ----> 1 from algothon2021ml import ML
#       2 import pandas as pd
#       3 import numpy as np
#
# ~/Desktop/AlgothonML/env/lib/python3.8/site-packages/algothon2021ml/__init__.py in <module>
# ----> 1 from .ml_challenge import ML
#
# ~/Desktop/AlgothonML/env/lib/python3.8/site-packages/algothon2021ml/ml_challenge.py in <module>
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import time
#       4
#       5
#
# ModuleNotFoundError: No module named 'pandas'

# %%
class MyPrediction(ML):
    def __init__(self,**parms):
        super(MyPrediction, self).__init__(**parms)
    
    def predict(self,data):
        return 1

# %%
Model = MyPrediction()

# %%
Model.run_test()
# Out:
#       Trade_date   Market  prediction
# 0     2018-01-02   bond_1           1
# 1     2018-01-11   bond_1           1
# 2     2018-01-25   bond_1           1
# 3     2018-01-26   bond_1           1
# 4     2018-01-29   bond_1           1
# ...          ...      ...         ...
# 2181  2021-03-01  stock_2           1
# 2182  2021-03-04  stock_2           1
# 2183  2021-03-05  stock_2           1
# 2184  2021-03-09  stock_2           1
# 2185  2021-03-11  stock_2           1
#
# [2186 rows x 3 columns]

# %%
Model.run_validate()
# Out:
#       Trade_date   Market  prediction
# 0     2016-01-04   bond_1           1
# 1     2016-01-05   bond_1           1
# 2     2016-01-06   bond_1           1
# 3     2016-01-11   bond_1           1
# 4     2016-01-13   bond_1           1
# ...          ...      ...         ...
# 1084  2017-10-27  stock_2           1
# 1085  2017-11-09  stock_2           1
# 1086  2017-11-16  stock_2           1
# 1087  2017-11-30  stock_2           1
# 1088  2017-12-15  stock_2           1
#
# [1089 rows x 3 columns]
